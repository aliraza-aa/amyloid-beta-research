# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_table("../system/simulations/confirmation0/nvt_temperature.xvg", delim_whitespace=True, skiprows=24, header=None)
# dataA = dataA.drop(columns="Unnamed: 0")
x = data[0]
y = data[1]

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("time (ps)")  # Add an x-label to the axes.
ax.set_ylabel("Temperature (K)")  # Add a y-label to the axes.
ax.set_title("Temperature Equilibration")
# Out:
# Text(0.5, 1.0, 'Temperature Equilibration')
